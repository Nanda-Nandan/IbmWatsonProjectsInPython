# %%
# %matplotlib notebook
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(3,2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(2,3,'*')

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
fig=Figure()
canvas=FigureCanvasAgg(fig)
ax=fig.add_subplot(111)
ax.plot(3,2,"*")
canvas.print_png('test.png')

# %%
# %%html
# <img src="test.png">
# Out:
# <img src="test.png">

# %%
plt.figure()
plt.plot(3,2,".")#data point is shown as . in figure
ax=plt.gca()#get axis
ax.axis([0,6,0,10])#set axis with min and amx value of axis
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 6, 0, 10]

# %%
ax.get_children()#Line2D object of output indicates its a data point
# Out:
# ...
#  Text(0.5,1,''),
#  Text(0,1,''),
#  Text(1,1,''),
# ...

# %%
import numpy as np
x=np.array([1,4,5,6,7,7])
y=x;
plt.figure()
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
x=np.array([1,2,3,4,5,6,7,7])
colors=['green']*(len(x)-3)
colors.append('red')
colors.append('red')
colors.append('red')
y=x;
plt.figure()
plt.scatter(x,y,s=100,c=colors)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
zip_test=zip([1,2,3,5,6],[7,8,9,0,3])

# %%
x,y=zip(*zip_test)
print(x)
print(y)
# Out:
# (1, 2, 3, 5, 6)
# (7, 8, 9, 0, 3)

# %%
zip_test=zip([1,2,3,5,6],[7,8,9,0,3])
list(zip_test)
# Out:
# [(1, 7), (2, 8), (3, 9), (5, 0), (6, 3)]

# %%
plt.figure()
plt.scatter(x[:2],y[:2],s=100,c='red',label="danger")
plt.scatter(x[2:],y[2:],s=100,c='green',label='safe')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('xlabel')#it will update in safe figure since we are not creating new figure object again
plt.ylabel('ylabel')
plt.title('xlabel vs ylabel')
# Out:
# Text(0.5,1,'xlabel vs ylabel')

# %%
plt.legend()

# %%
plt.legend(loc=4,frameon=False,title='legend')

# %%
linear_data=np.array([1,2,3,4,5,6,7])
quadratic_data=linear_data**2
plt.figure()
plt.plot(linear_data,'-o',quadratic_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
plt.plot([7,6,9],'--r')

# %%
plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.title('xlabel vs ylabel')
plt.legend(["linear","quadratic","dotted"])

# %%
plt.gca().fill_between(range(len(linear_data)),linear_data,quadratic_data,facecolor='blue',alpha=0.5)
#fill the colours between the lines provided input the array of values of two line

# %%
plt.figure()
obser_dates=np.arange('2018-01-01','2018-01-08',dtype='datetime64[D]')
print(obser_dates)
plt.plot(obser_dates,linear_data,'-o',obser_dates,quadratic_data,'-o')#but here x-axis is not shown in date,this the problem with normal date tie object
# Out:
# <img src="data:image/png;base64,..." width="640">
# ['2018-01-01' '2018-01-02' '2018-01-03' '2018-01-04' '2018-01-05'
#  '2018-01-06' '2018-01-07']
# ...

# %%
import pandas as pd
obser_dates=np.arange('2018-01-01','2018-01-08',dtype='datetime64[D]')
#plt.figure()
print(obser_dates)
obser_dates=list(map(pd.to_datetime,obser_dates))#since map returns itereable object we can not pass directly to plot function,we have to make it array or list
print(obser_dates)
#plt.plot(obser_dates,linear_data,'-o',obser_dates,quadratic_data,'-o')
# Out:
# ['2018-01-01' '2018-01-02' '2018-01-03' '2018-01-04' '2018-01-05'
#  '2018-01-06' '2018-01-07']
# [Timestamp('2018-01-01 00:00:00'), Timestamp('2018-01-02 00:00:00'), Timestamp('2018-01-03 00:00:00'), Timestamp('2018-01-04 00:00:00'), Timestamp('2018-01-05 00:00:00'), Timestamp('2018-01-06 00:00:00'), Timestamp('2018-01-07 00:00:00')]

# %%
plt.figure()
xvals=range(len(linear_data))
plt.bar(xvals,linear_data,width=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 7 artists>

# %%
new_xvals=[]
for item in xvals:
    new_xvals.append(item+0.3)

plt.bar(new_xvals,quadratic_data,width=0.4,color='red')
# Out:
# <Container object of 7 artists>

# %%
from random import randint
err_data=[randint(1,26) for x in range(len(linear_data))]
plt.bar(xvals,linear_data,width=0.4,yerr=err_data)#shows the error data in yaxis
# Out:
# <Container object of 7 artists>

# %%
plt.figure()
plt.bar(xvals,linear_data,width=0.4,color='b')
plt.bar(xvals,quadratic_data,width=0.6,bottom=linear_data,color='r')#create both plot in same fig bottom part linear data and top quadratic data
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 7 artists>

# %%
plt.figure()#to make it horizontal bar three things to change plt.bar to plt.barh and width to height and bottom to left
plt.barh(xvals,linear_data,height=0.4,color='b')
plt.barh(xvals,quadratic_data,height=0.6,left=linear_data,color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 7 artists>

# %%
#Remove ticks along both axis and remove xlabel
plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)
plt.tick_params(
    #axis='x',          # changes apply to the x-axis only
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    left='off', 
    right='off' ,
    labelbottom='on',
    labelleft='off') #bottom label off

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Remove Frame
plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

for spine in plt.gca().spines.values():
    spine.set_visible(False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#change colour of bar

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar colors to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar color to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
# remove the Y label since bars are directly labeled
#plt.ylabel('% Popularity', alpha=0.8)
              
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
# direct label each bar with Y axis values
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
